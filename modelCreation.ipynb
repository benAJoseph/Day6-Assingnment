# %%
import pandas as pd
df = pd.read_csv("Covid_tweets_US.csv")

review_df = df[['text','Polarity']]

review_df = review_df[review_df['Polarity'] != 'Neutral']

review_df["Polarity"].value_counts()
# Out:
# Positive    154698
# Negative     64326
# Name: Polarity, dtype: int64

# %%
sentiment_label = review_df.Polarity.factorize()
sentiment_label
# Out:
# (array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#  Index(['Positive', 'Negative'], dtype='object'))

# %%
review_df['Label'] = review_df.Polarity.map({'Positive':0, 'Negative':1})

# %%
review_df.head()
# Out:
#                                                 text  Polarity  Label
# 0  mayor janefortampa janecastor done amazing job...  Positive      0
# 1  friend genezahas died fr coronavirus alamedaco...  Positive      0
# 3  keep questioning normal look like get nightmar...  Positive      0
# 4  ask better view making call amykennedy tonight...  Positive      0
# 5  lovely seder homemade matzah secret making mat...  Positive      0

# %%
X = review_df.text
y = review_df.Label
print(X.shape)
print(y.shape)
# Out:
# (219024,)
# (219024,)

# %%
X
# Out:
# 0         mayor janefortampa janecastor done amazing job...
# 1         friend genezahas died fr coronavirus alamedaco...
# 3         keep questioning normal look like get nightmar...
# 4         ask better view making call amykennedy tonight...
# 5         lovely seder homemade matzah secret making mat...
#                                 ...
# 357491    weirdest quarentine meal straight meatball sau...
# 357493    really funny people tweeple covid stayhome bit...
# 357494    famous santa monica stair shut covid lot folk ...
# 357495    surreal nature daily covid routine first ita t...
# 357497            road happiness covid wewillgetthroughthis
# Name: text, Length: 219024, dtype: object

# %%
y
# Out:
# 0         0
# 1         0
# 3         0
# 4         0
# 5         0
#          ..
# 357491    0
# 357493    0
# 357494    0
# 357495    0
# 357497    0
# Name: Label, Length: 219024, dtype: int64

# %%
from sklearn.model_selection  import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y,test_size = 0.20, random_state =42)

# %%
X_train.shape
# Out:
# (175219,)

# %%
y_train.shape
# Out:
# (175219,)

# %%
print(X_test.shape)
print(y_test.shape)
# Out:
# (43805,)
# (43805,)

# %%
from sklearn.feature_extraction.text import CountVectorizer
vect = CountVectorizer()

# %%
vect.fit(X_train)
vect.vocabulary_
# Out:
# {'buying': 13969,
#  'local': 61966,
#  'vegetable': 114582,
#  'help': 46232,
#  'stay': 100894,
#  'business': 13824,
#  'farmer': 35837,
#  'market': 64843,
#  'closed': 19173,
#  'due': 30672,
#  'covid': 22255,
#  'pandemic': 79159,
#  'yasukochifamilyfarm': 120719,
#  'oceanside': 76466,
#  'taking': 104369,
#  'produce': 84754,
#  'directly': 27608,
#  'home': 47471,
#  'delivering': 26105,
#  'csa': 23420,
#  'box': 12121,
#  'full': 39835,
#  'fresh': 39307,
#  'agriculture': 1813,
#  'go': 42157,
#  'forever': 38448,
#  'least': 59920,
#  'never': 73102,
#  'called': 14390,
#  'american': 3326,
#  'family': 35672,
#  'field': 36717,
#  'millerpark': 68155,
#  'baseball': 7998,
#  'mlb': 68910,
#  'brewer': 12677,
#  'positivity': 83470,
#  'thatgirlondeck': 106175,
#  'schrades': 94199,
#  'please': 82497,
#  'step': 101413,
#  'away': 6902,
#  'thanks': 106038,
#  'evildead': 34579,
#  'ashvsevildead': 5743,
#  'horror': 47926,
#  'horrormovies': 47931,
#  'groovybruce': 43860,
#  'coronavirus': 21513,
#  'south': 99418,
#  'yulee': 121373,
#  'fl': 37418,
#  'weigh': 117393,
#  'station': 100857,
#  'truck': 110581,
#  'currently': 23879,
#  'check': 17041,
#  'empty': 32858,
#  'place': 82250,
#  'mequedoencasa': 67028,
#  'quarantine': 86248,
#  'en': 32915,
#  'nanban': 71834,
#  'kan': 56110,
#  'restaurant': 89979,
#  'new': 73149,
#  'faq': 35806,
#  'cll': 19137,
#  'published': 85648,
#  'ash': 5687,
#  'hematology': 46334,
#  'next': 73590,
#  'stimulus': 101753,
#  'must': 71157,
#  'include': 50680,
#  'youth': 121264,
#  'young': 121140,
#  'adult': 1318,
#  'worker': 119633,
#  'unemployed': 112648,
#  'clasp': 18798,
#  'dc': 25317,
#  'thenyec': 107032,
#  'idea': 49429,
#  'happen': 44959,
#  'woke': 119354,
#  'morning': 69830,
#  'chilling': 17555,
#  'incredible': 50732,
#  'buddyrich': 13451,
#  'amp': 3592,
#  'big': 9917,
#  'band': 7673,
#  'ghsstrings': 41504,
#  'ghsartist': 41502,
#  'fender': 36510,
#  'seymourduncan': 95791,
#  'fenderbass': 36511,
#  'sadowskybass': 92620,
#  'stayathome': 100907,
#  'resist': 89824,
#  'jazz': 53728,
#  'blue': 11172,
#  'bluesmusic': 11251,
#  'music': 71059,
#  'thetroubadours': 107503,
#  'corona': 21235,
#  'love': 62646,
#  'china': 17580,
#  'korea': 58131,
#  'italy': 52758,
#  'starting': 100731,
#  'nd': 72573,
#  'wave': 116678,
#  'spanish': 99610,
#  'flu': 37877,
#  'worse': 119870,
#  'st': 100443,
#  'restock': 90013,
#  'hospital': 47960,
#  'keep': 56648,
#  'lost': 62531,
#  'war': 116356,
#  'let': 60339,
#  'back': 7201,
#  'stupid': 102594,
#  'drug': 30448,
#  'instead': 51665,
#  'usa': 113589,
#  'changed': 16715,
#  'channel': 16741,
#  'cnn': 19413,
#  'continue': 20768,
#  'air': 1972,
#  'boyking': 12184,
#  'realdonaldtrump': 87857,
#  'propaganda': 85024,
#  'session': 95625,
#  'curated': 23804,
#  'hour': 48080,
#  'chill': 17542,
#  'collab': 19831,
#  'weddingpro': 117238,
#  'work': 119616,
#  'threw': 108053,
#  'ton': 109194,
#  'hidden': 46756,
#  'gem': 40887,
#  'link': 61303,
#  'enjoy': 33221,
#  'djlife': 28386,
#  'traveldj': 110089,
#  'quarantunes': 86466,
#  'quarantineandchill': 86254,
#  'sanity': 93293,
#  'delaying': 26045,
#  'stimuluspayment': 101763,
#  'without': 119177,
#  'funding': 39919,
#  'million': 68165,
#  'kennedy': 56977,
#  'foundation': 38735,
#  'certainly': 16481,
#  'stalled': 100555,
#  'process': 84712,
#  'right': 90707,
#  'nancy': 71836,
#  'jeez': 53903,
#  'someone': 99045,
#  'diagnosed': 27145,
#  'single': 97388,
#  'thing': 107691,
#  'heartbreaking': 45944,
#  'everyone': 34513,
#  'safe': 92637,
#  'hold': 47325,
#  'close': 19170,
#  'tell': 105482,
#  'friend': 39408,
#  'unitedhealth': 112884,
#  'president': 84227,
#  'andrew': 3860,
#  'witty': 119209,
#  'leading': 59800,
#  'vaccine': 114125,
#  'development': 26942,
#  'insider': 51493,
#  'unable': 112310,
#  'attend': 6375,
#  'nothing': 75150,
#  'fight': 36761,
#  'february': 36275,
#  'fuck': 39684,
#  'nola': 74545,
#  'order': 77909,
#  'issued': 52689,
#  'bother': 12012,
#  'mayor': 65768,
#  'governor': 43019,
#  'one': 77255,
#  'highest': 46807,
#  'outbreak': 78371,
#  'country': 22098,
#  'people': 80703,
#  'really': 87961,
#  'dontbeaspreader': 29079,
#  'coronavirustruth': 21734,
#  'god': 42236,
#  'damned': 24487,
#  'lol': 62204,
#  'essential': 34042,
#  'essentialaf': 34043,
#  'fuckenlegend': 39706,
#  'happyfriday': 45007,
#  'bc': 8324,
#  'environmental': 33433,
#  'anyone': 4532,
#  'surprised': 103542,
#  'crap': 22789,
#  'ing': 51204,
#  'television': 105470,
#  'medium': 66523,
#  'actually': 918,
#  'wanted': 116340,
#  'awful': 6932,
#  'situation': 97554,
#  'would': 119917,
#  'look': 62333,
#  'like': 61080,
#  'fakenews': 35547,
#  'entertainment': 33353,
#  'prayforthesick': 83930,
#  'know': 57955,
#  'mess': 67179,
#  'tear': 105224,
#  'article': 5450,
#  'much': 70662,
#  'needed': 72730,
#  'change': 16712,
#  'scenery': 94026,
#  'longrun': 62310,
#  'initforthelongrun': 51291,
#  'ncr': 72545,
#  'changeofscenery': 16725,
#  'quaruntinelife': 86567,
#  'quaruntine': 86566,
#  'ninjastyle': 74056,
#  'runningisntcancelled': 92182,
#  'runnersrresilient': 92171,
#  'trainingdoesntstop': 109854,
#  'need': 72715,
#  'yesterday': 120867,
#  'passed': 79772,
#  'tsa': 111111,
#  'based': 8015,
#  'florida': 37749,
#  'number': 75649,
#  'test': 105769,
#  'positive': 83440,
#  'shut': 96940,
#  'airport': 2026,
#  'govrondesantis': 43094,
#  'vp': 115880,
#  'remember': 89076,
#  'massive': 65376,
#  'unemployment': 112653,
#  'released': 88951,
#  'past': 79824,
#  'two': 111680,
#  'week': 117288,
#  'elected': 32143,
#  'pay': 80163,
#  'lack': 58736,
#  'leadership': 59778,
#  'key': 57183,
#  'word': 119593,
#  'spike': 99880,
#  'yet': 120876,
#  'long': 62256,
#  'haul': 45405,
#  'frightening': 39437,
#  'interact': 51806,
#  'daily': 24286,
#  'worry': 119867,
#  'bringing': 12895,
#  'stress': 102339,
#  'heavy': 46033,
#  'slow': 98030,
#  'spread': 100152,
#  'taurus': 104754,
#  'protection': 85168,
#  'inc': 50610,
#  'received': 88171,
#  'postcard': 83510,
#  'mail': 63869,
#  'cdc': 16153,
#  'white': 118379,
#  'house': 48094,
#  'outlining': 78441,
#  'guideline': 44134,
#  'america': 3316,
#  'santabarbara': 93333,
#  'worldhealthorganization': 119790,
#  'californiacoronavirus': 14338,
#  'security': 94887,
#  'securityofficer': 94892,
#  'trumppressconf': 110928,
#  'democrat': 26229,
#  'year': 120763,
#  'trade': 109769,
#  'agreement': 1808,
#  'nafta': 71722,
#  'tpp': 109698,
#  'deliberately': 26073,
#  'stopped': 102030,
#  'manufacturing': 64522,
#  'good': 42599,
#  'car': 15036,
#  'benefitted': 9176,
#  'gifted': 41565,
#  'trump': 110678,
#  'wrong': 120090,
#  'everything': 34534,
#  'report': 89531,
#  'death': 25540,
#  'day': 25178,
#  'yes': 120842,
#  'govmlg': 43077,
#  'nm': 74260,
#  'great': 43447,
#  'plan': 82297,
#  'safety': 92691,
#  'munication': 70856,
#  'listens': 61440,
#  'expert': 34926,
#  'appears': 4738,
#  'best': 9454,
#  'used': 113731,
#  'patient': 79924,
#  'require': 89701,
#  'liter': 61484,
#  'oxygen': 78764,
#  'intubated': 52063,
#  'halt': 44715,
#  'cytokinestorm': 24181,
#  'lower': 62886,
#  'humor': 48653,
#  'alexa': 2416,
#  'queen': 86602,
#  'york': 121042,
#  'dallas': 24404,
#  'county': 22121,
#  'latest': 59365,
#  'update': 113360,
#  'visit': 115448,
#  'website': 117180,
#  'click': 19027,
#  'addisontx': 1072,
#  'doctor': 28592,
#  'investigate': 52114,
#  'strange': 102181,
#  'rare': 87434,
#  'childhood': 17482,
#  'kawasakidisease': 56441,
#  'could': 22032,
#  'mon': 69412,
#  'denominator': 26361,
#  'endothelial': 33076,
#  'dysfunction': 31018,
#  'sarscov': 93532,
#  'infectiousdisease': 51072,
#  'robbie': 91161,
#  'sack': 92544,
#  'peanut': 80375,
#  'time': 108451,
#  'squirrel': 100354,
#  'gotta': 42934,
#  'eat': 31306,
#  'find': 36978,
#  'better': 9629,
#  'job': 54696,
#  'saying': 93818,
#  'yeah': 120757,
#  'invest': 52107,
#  'food': 38184,
#  'abrohilo': 396,
#  'epa': 33491,
#  'venezuela': 114645,
#  'vean': 114527,
#  'esto': 34165,
#  'la': 58647,
#  'gente': 40993,
#  'olvida': 77125,
#  'pido': 81837,
#  'trama': 109874,
#  'de': 25435,
#  'corrupcion': 21864,
#  'vzla': 115984,
#  'los': 62485,
#  'parasitos': 79458,
#  'rojos': 91482,
#  'narcos': 71923,
#  'esa': 33860,
#  'organizaci': 77970,
#  'criminal': 23053,
#  'abr': 371,
#  'ultimahora': 112190,
#  'sevan': 95680,
#  'cuarentena': 23594,
#  'domingoderesurreccion': 28914,
#  'felizdomingo': 36445,
#  'semanasanta': 95187,
#  'sinluz': 97428,
#  'kjlh': 57775,
#  'concert': 20127,
#  'series': 95539,
#  'tonight': 109214,
#  'pm': 82720,
#  'starring': 100714,
#  'donny': 29034,
#  'hathaway': 45386,
#  'tunen': 111335,
#  'kevinnashshow': 57169,
#  'hear': 45914,
#  'live': 61606,
#  'recorded': 88270,
#  'entirety': 33371,
#  'radiofreekjlh': 86992,
#  'turn': 111385,
#  'surround': 103558,
#  'sound': 99365,
#  'system': 104126,
#  'fully': 39859,
#  'knashmusic': 57886,
#  'importantly': 50437,
#  'healthy': 45852,
#  'thank': 106002,
#  'every': 34475,
#  'person': 80981,
#  'working': 119679,
#  'around': 5330,
#  'clock': 19144,
#  'real': 87814,
#  'hero': 46526,
#  'crisis': 23097,
#  'coronaviruspandemic': 21680,
#  'science': 94254,
#  'salt': 92931,
#  'lake': 58893,
#  'stayhomestaysafe': 101093,
#  'extended': 35053,
#  'may': 65713,
#  'though': 107996,
#  'earlier': 31103,
#  'another': 4289,
#  'note': 75105,
#  'barber': 7819,
#  'shop': 96654,
#  'see': 94916,
#  'hair': 44583,
#  'get': 41215,
#  'still': 101688,
#  'semi': 95199,
#  'manageable': 64279,
#  'seems': 94944,
#  'hopeless': 47839,
#  'today': 108891,
#  'losing': 62519,
#  'faith': 35502,
#  'trying': 111093,
#  'hard': 45092,
#  'istandwiththepresident': 52699,
#  'chinavirus': 17615,
#  'backtowork': 7277,
#  'prior': 84562,
#  'hated': 45361,
#  'trash': 110029,
#  'tv': 111469,
#  'addicted': 1057,
#  'dayfiance': 25195,
#  'shit': 96548,
#  'golden': 42451,
#  'cantstopwontstop': 14872,
#  'give': 41775,
#  'terrible': 105716,
#  'advice': 1385,
#  'keto': 57107,
#  'wanna': 116334,
#  'suck': 102811,
#  'virus': 115395,
#  'might': 67913,
#  'spreading': 100164,
#  'even': 34419,
#  'probably': 84681,
#  'stayhome': 101000,
#  'socialdistancing': 98695,
#  'neverreopen': 73128,
#  'yepp': 120833,
#  'getting': 41360,
#  'punishment': 85806,
#  'state': 100793,
#  'largest': 59190,
#  'increase': 50728,
#  'successful': 102785,
#  'distribution': 28177,
#  'kckps': 56539,
#  'esl': 33949,
#  'migrant': 67929,
#  'team': 105030,
#  'avenueoflifekc': 6780,
#  'volunteer': 115749,
#  'partner': 79675,
#  'serving': 95602,
#  'kckschools': 56541,
#  'kckpsontrack': 56540,
#  'boat': 11391,
#  'parade': 79399,
#  'social': 98660,
#  'distancing': 28122,
#  'occurring': 76451,
#  'arrowhead': 5380,
#  'abc': 219,
#  'news': 73366,
#  'azfamily': 7048,
#  'behuman': 8942,
#  'saferathome': 92671,
#  'humanswin': 48614,
#  'knptailgate': 58003,
#  'arizona': 5195,
#  'knew': 57901,
#  'bring': 12880,
#  'hitting': 47141,
#  'question': 86679,
#  'many': 64529,
#  'fabric': 35228,
#  'mask': 65199,
#  'straw': 102225,
#  'hat': 45351,
#  'facemask': 35285,
#  'special': 99715,
#  'pathcast': 79897,
#  'tomorrow': 109170,
#  'taiwan': 104280,
#  'mannanrifat': 64449,
#  'twmarkc': 111679,
#  'joebiden': 54751,
#  'campaign': 14582,
#  'final': 36919,
#  'way': 116704,
#  'dementiadon': 26199,
#  'reality': 87919,
#  'show': 96806,
#  'present': 84198,
#  'false': 35621,
#  'narrative': 71937,
#  'promise': 84971,
#  'cloroquine': 19157,
#  'chlorox': 17741,
#  'lysol': 63445,
#  'openusa': 77687,
#  'disappear': 27690,
#  'killing': 57459,
#  'base': 7997,
#  'bodybags': 11492,
#  'magats': 63746,
#  'tatoo': 104730,
#  'alexmcdaniel': 2474,
#  'claim': 18689,
#  'candle': 14726,
#  'robyntannehill': 91294,
#  'think': 107722,
#  'excellent': 34700,
#  'however': 48252,
#  'feel': 36368,
#  'strongly': 102442,
#  'ahead': 1853,
#  'vega': 114554,
#  'georgia': 41085,
#  'regarding': 88711,
#  'loose': 62395,
#  'weight': 117397,
#  'obese': 76293,
#  'started': 100729,
#  'diet': 27310,
#  'ugh': 112074,
#  'rate': 87487,
#  'able': 316,
#  'approved': 4837,
#  'governmenthelpisajoke': 43011,
#  'done': 28992,
#  'made': 63603,
#  'triple': 110427,
#  'layerd': 59648,
#  'tightly': 108357,
#  'woven': 119928,
#  'cotton': 22001,
#  'filter': 36905,
#  'insert': 51480,
#  'self': 95075,
#  'cheryl': 17252,
#  'isolation': 52625,
#  'seamstress': 94684,
#  'tailor': 104268,
#  'defund': 25963,
#  'gut': 44299,
#  'aca': 486,
#  'insurance': 51721,
#  'rely': 89034,
#  'replacement': 89474,
#  'youreanidiot': 121189,
#  'trumpfailedus': 110768,
#  'takemyballandgohome': 104328,
#  'disgusting': 27866,
#  'yousosmart': 121259,
#  'cautious': 15926,
#  'information': 51165,
#  'asia': 5749,
#  'second': 94819,
#  'round': 91829,
#  'fall': 35588,
#  'wearamask': 116914,
#  'stats': 100871,
#  'city': 18401,
#  'cincinnati': 18248,
#  'case': 15560,
#  'limit': 61182,
#  'impeachment': 50367,
#  'distracted': 28156,
#  'caught': 15898,
#  'flat': 37488,
#  'footed': 38325,
#  'border': 11837,
#  'apparently': 4729,
#  'charge': 16818,
#  'developing': 26941,
#  'also': 2972,
#  'radical': 86977,
#  'sjw': 97630,
#  'hate': 45357,
#  'outta': 78514,
#  'realtor': 88015,
#  'alabama': 2198,
#  'little': 61515,
#  'farmhouse': 35847,
#  'peace': 80330,
#  'realtorlife': 88021,
#  'southern': 99457,
#  'living': 61732,
#  'say': 93801,
#  'fast': 35948,
#  'moving': 70212,
#  'maybe': 65724,
#  'longer': 62273,
#  'originally': 78012,
#  'thought': 108000,
#  'fareedzakaria': 35817,
#  'harvardchansph': 45285,
#  'jennifernuzzo': 54087,
#  'im': 50061,
#  'nicotine': 73871,
#  'free': 39067,
#  'scary': 93986,
#  'heck': 46051,
#  'thinking': 107745,
#  'avoid': 6846,
#  'scared': 93957,
#  'lung': 63245,
#  'woykdnt': 119942,
#  'catch': 15734,
#  'strong': 102423,
#  'pulling': 85737,
#  'kickthehabit': 57339,
#  'nicotineworsethanheroin': 73872,
#  'stayhomesavelives': 101074,
#  'opening': 77632,
#  'eglaze': 31959,
#  'chronicle': 18042,
#  'want': 116339,
#  'wingonomics': 118997,
#  'bobrathbuntv': 11445,
#  'dmillions': 28488,
#  'williams': 118835,
#  'nickicollen': 73810,
#  'jglazespeaks': 54357,
#  'joining': 55028,
#  'instagramlive': 51607,
#  'finance': 36945,
#  'truetoatlanta': 110657,
#  'atlantadream': 6235,
#  'olympics': 77142,
#  'mentalhealth': 66941,
#  'concerned': 20123,
#  'folk': 38078,
#  'sense': 95411,
#  'wide': 118661,
#  'open': 77600,
#  'ultimately': 112196,
#  'make': 63982,
#  'call': 14377,
#  'normal': 74838,
#  'newnormal': 73318,
#  'quarantinelife': 86372,
#  'butfirstcoffee': 13907,
#  'coffee': 19668,
#  'latte': 59428,
#  'latteart': 59429,
#  'espresso': 34012,
#  'homebarista': 47480,
#  'coffeetime': 19695,
#  'cafemorrissiatto': 14204,
#  'projectseth': 84932,
#  'afspnational': 1615,
#  'betsbikers': 9618,
#  'reason': 88067,
#  'encourage': 32976,
#  'bikers': 10083,
#  'ride': 90632,
#  'understand': 112560,
#  'mental': 66935,
#  'health': 45706,
#  'press': 84275,
#  'twill': 111580,
#  'attn': 6409,
#  'wellington': 117507,
#  'parent': 79478,
#  'munity': 70878,
#  'service': 95586,
#  'department': 26432,
#  'child': 17464,
#  'challenging': 16655,
#  'monday': 69431,
#  'friday': 39363,
#  'assistance': 6008,
#  'distance': 28106,
#  'learning': 59889,
#  'inthistogether': 51988,
#  'response': 89942,
#  'headhunter': 45646,
#  'resume': 90057,
#  'generalcounsel': 40919,
#  'exec': 34759,
#  'listing': 61459,
#  'spearheaded': 99710,
#  'pany': 79320,
#  'exp': 34857,
#  'mad': 63569,
#  'document': 28640,
#  'eating': 31336,
#  'meat': 66272,
#  'knowing': 57961,
#  'processed': 84713,
#  'died': 27289,
#  'plicit': 82612,
#  'choose': 17794,
#  'horrible': 47914,
#  'beyond': 9718,
#  'biggest': 9983,
#  'fear': 36228,
#  'true': 110621,
#  'wmd': 119299,
#  'academic': 498,
#  'experience': 34906,
#  'level': 60506,
#  'excruciatingly': 34747,
#  'painful': 78972,
#  'savelives': 93706,
#  'intensivecare': 51790,
#  'london': 62228,
#  'first': 37187,
#  'freak': 39012,
#  'coronavirusoutbreak': 21673,
#  'misinformation': 68515,
#  'flattening': 37515,
#  'since': 97334,
#  'program': 84866,
#  'sending': 95310,
#  'video': 115004,
#  'tweet': 111524,
#  'failure': 35437,
#  'leader': 59769,
#  'lead': 59765,
#  'allowing': 2816,
#  'narcissist': 71915,
#  'liar': 60682,
#  'take': 104291,
#  'wishing': 119122,
#  'brave': 12431,
#  'care': 15134,
#  'caring': 15224,
#  'world': 119768,
#  'always': 3064,
#  'nationaldoctorsday': 72120,
#  'closing': 19209,
#  'housing': 48155,
#  'allny': 2792,
#  'aoc': 4559,
#  'jawanza': 53646,
#  'vocalnewyork': 115659,
#  'talking': 104423,
#  'homelessness': 47556,
#  'nyc': 75867,
#  'depression': 26503,
#  'yorkers': 121050,
#  'homelesscantstayhome': 47549,
#  'nevada': 73085,
#  'jumping': 55674,
#  'overnight': 78617,
#  'reported': 89539,
#  'story': 102115,
#  'raised': 87151,
#  'yr': 121327,
#  'old': 76995,
#  'ww': 120290,
#  'vet': 114845,
#  'relief': 88985,
#  'uk': 112136,
#  'captaintommoore': 15007,
#  'awlasky': 6943,
#  'jryan': 55415,
#  'simplysallyh': 97307,
#  'rr': 91929,
#  'pirate': 82082,
#  'fisherman': 37271,
#  'samanthajohnson': 93011,
#  'oberreimer': 76291,
#  'suziday': 103735,
#  'jay': 53671,
#  'eatz': 31378,
#  'cbp': 16009,
#  'cindy': 18264,
#  'itsallglamr': 52857,
#  'jflorez': 54349,
#  'dracaenawines': 29657,
#  'drazzari': 29782,
#  'fionamorgan': 37106,
#  'joukesp': 55287,
#  'julianna': 55616,
#  'glass': 41884,
#  'gailbenzler': 40241,
#  'joneill': 55108,
#  'rombach': 91554,
#  'winecheesefri': 118966,
#  'sashaeats': 93544,
#  'thebrick': 106409,
#  'tomthomas': 109186,
#  'stevehammactor': 101560,
#  'divavinophile': 28227,
#  'russellvine': 92257,
#  'oh': 76760,
#  'yea': 120752,
#  'run': 92136,
#  'wait': 116097,
#  'calorie': 14457,
#  'count': 22072,
#  'add': 1049,
#  'nearly': 72639,
#  'total': 109486,
#  'confirmed': 20286,
#  'nears': 72642,
#  'via': 114901,
#  'miamiherald': 67495,
#  'mean': 66243,
#  'thelastdance': 106851,
#  'despite': 26760,
#  'among': 3572,
#  'resident': 89791,
#  'staff': 100492,
#  'alamedacounty': 2225,
#  'hayward': 45520,
#  'gateway': 40623,
#  'center': 16366,
#  'inside': 51485,
#  'unclear': 112412,
#  'amazing': 3194,
#  'recognition': 88242,
#  'techforgood': 105251,
#  'rockstars': 91369,
#  'ladygaga': 58809,
#  'encouraging': 32982,
#  'create': 22881,
#  'solution': 99003,
#  'submit': 102708,
#  'april': 4864,
#  'deployed': 26468,
#  'challenge': 16649,
#  'deadline': 25460,
#  'july': 55660,
#  'given': 41805,
#  'availability': 6746,
#  'testing': 105791,
#  'high': 46789,
#  'prevalence': 84372,
#  'asymptomatic': 6123,
#  'individual': 50889,
#  'wear': 116912,
#  'especially': 33972,
#  'healthcare': 45719,
#  'provider': 85345,
#  'frontline': 39526,
#  'responder': 89930,
#  'tireless': 108665,
#  'passion': 79781,
#  'bravery': 12440,
#  'healthcareheroes': 45731,
#  'widespread': 118675,
#  'effect': 31886,
#  'threatening': 108033,
#  'vulnerable': 115948,
#  'operating': 77708,
#  'offering': 76622,
#  'remotely': 89133,
#  'remain': 89039,
#  'mitted': 68787,
#  'finding': 36991,
#  'creative': 22910,
#  'equitable': 33628,
#  'socialimpact': 98740,
#  'read': 87735,
#  'newsletter': 73410,
#  'related': 88916,
#  'blog': 11044,
#  'post': 83497,
#  'continues': 20770,
#  'use': 113729,
#  'push': 85934,
#  'xenophobic': 120420,
#  'policy': 82987,
#  'favorite': 36081,
#  'target': 104624,
#  'immigrant': 50243,
#  'slap': 97844,
#  'face': 35250,
#  'government': 43000,
#  'left': 60024,
#  'said': 92774,
#  'citizen': 18372,
#  'married': 64978,
#  'man': 64276,
#  'mexico': 67344,
#  'already': 2964,
#  'stressful': 102351,
#  'black': 10577,
#  'die': 27287,
#  'rapidly': 87401,
#  'specifically': 99751,
#  'gay': 40683,
#  'partying': 79694,
#  'sure': 103478,
#  'ft': 39640,
#  'walking': 116202,
#  'closet': 19195,
#  'course': 22167,
#  'school': 94135,
#  'group': 43900,
#  'student': 102520,
#  'ever': 34448,
#  'march': 64592,
#  'th': 105976,
#  'last': 59265,
#  'goodbye': 42605,
#  'nj': 74144,
#  'according': 598,
#  'kff': 57221,
#  'jersey': 54198,
#  'crazy': 22836,
#  'regulation': 88800,
#  'flipping': 37672,
#  'aspect': 5913,
#  'reading': 87750,
#  'everyday': 34485,
#  'road': 91115,
#  'cbsn': 16036,
#  'carry': 15481,
#  'task': 104692,
#  'force': 38362,
#  'briefing': 12811,
#  'et': 34194,
#  'reenaninan': 88583,
#  'anchor': 3764,
#  'coverage': 22217,
#  'anlaysis': 4157,
#  'plus': 82687,
#  'official': 76644,
#  'cbsnews': 16039,
#  'alwayson': 3079,
#  'robjgifford': 91257,
#  'book': 11727,
#  'weekly': 117308,
#  'beginning': 8889,
#  'novelette': 75365,
#  'burned': 13750,
#  'toast': 108850,
#  'lot': 62554,
#  'hope': 47815,
#  'ea': 31035,
#  'freebook': 39084,
#  'freeonkindle': 39185,
#  'domesticviolence': 28893,
#  'pleased': 82501,
#  'quoted': 86818,
#  ...}

# %%
vect = CountVectorizer(stop_words='english')

# %%
vectorizer = vect.fit(X)

# %%
vect.vocabulary_
# Out:
# {'mayor': 67361,
#  'janefortampa': 54730,
#  'janecastor': 54724,
#  'amazing': 3262,
#  'job': 55991,
#  'keeping': 58040,
#  'resident': 91964,
#  'cityoftampa': 19023,
#  'healthy': 46922,
#  'safe': 94897,
#  'applauded': 4853,
#  'work': 122559,
#  'winning': 121949,
#  'war': 119224,
#  'covid': 22791,
#  'leadership': 61205,
#  'action': 854,
#  'friend': 40305,
#  'genezahas': 41901,
#  'died': 27939,
#  'fr': 39746,
#  'coronavirus': 22028,
#  'alamedacounty': 2281,
#  'born': 12169,
#  'westoakland': 120727,
#  'greek': 44536,
#  'munity': 72591,
#  'true': 113332,
#  'oakland': 78071,
#  'citizen': 18819,
#  'quietly': 88838,
#  'glued': 43067,
#  'city': 18848,
#  'worked': 122576,
#  'chair': 17017,
#  'treasurer': 112895,
#  'ballotmeasures': 7760,
#  'oaklandschools': 78077,
#  'rip': 93019,
#  'questioning': 88779,
#  'normal': 76660,
#  'look': 63822,
#  'like': 62536,
#  'nightmare': 75720,
#  'people': 82643,
#  'avoid': 6986,
#  'crowded': 23816,
#  'place': 84235,
#  'concert': 20612,
#  'sport': 102497,
#  'event': 35230,
#  'theater': 108906,
#  'mall': 65744,
#  'thing': 110331,
#  'past': 81741,
#  'ask': 5913,
#  'better': 9846,
#  'view': 117893,
#  'making': 65628,
#  'amykennedy': 3746,
#  'tonight': 111888,
#  'amy': 3733,
#  'staff': 102943,
#  'vols': 118585,
#  'daily': 24861,
#  'senior': 97657,
#  'sj': 99978,
#  'check': 17445,
#  'amp': 3672,
#  'connect': 20900,
#  'resource': 92038,
#  'amid': 3554,
#  'proud': 87321,
#  'campaign': 14931,
#  'invested': 53338,
#  'nj': 75950,
#  'lovely': 64242,
#  'seder': 97220,
#  'homemade': 48678,
#  'matzah': 67205,
#  'secret': 97157,
#  'salting': 95208,
#  'baking': 7680,
#  'yummmmm': 124375,
#  'passover': 81721,
#  'shade': 98241,
#  'winchester': 121855,
#  'massachusetts': 66903,
#  'math': 67055,
#  'department': 27063,
#  'plymouth': 84702,
#  'high': 47880,
#  'school': 96429,
#  'definitely': 26560,
#  'missing': 70250,
#  'student': 105013,
#  'really': 90094,
#  'understand': 115318,
#  'exponential': 35803,
#  'growth': 44979,
#  'graph': 44361,
#  'good': 43586,
#  'following': 38982,
#  'safer': 94931,
#  'home': 48578,
#  'policy': 84991,
#  'mathnerds': 67080,
#  'mathteacher': 67082,
#  'plymouthschools': 84705,
#  'april': 4965,
#  'monthly': 71335,
#  'ww': 123253,
#  'meeting': 68193,
#  'zoom': 124727,
#  'thursday': 110826,
#  'pm': 84715,
#  'dm': 29136,
#  'code': 20091,
#  'join': 56326,
#  'continue': 21268,
#  'reach': 89839,
#  'know': 59338,
#  'great': 44460,
#  'need': 74488,
#  'help': 47311,
#  'amidst': 3555,
#  'crisis': 23652,
#  'woburnhelpingwoburn': 122278,
#  'cbsla': 16417,
#  'abc': 225,
#  'ktla': 59798,
#  'cagovernor': 14565,
#  'gavinnewsom': 41602,
#  'childcare': 17890,
#  'provider': 87402,
#  'essential': 34837,
#  'worker': 122577,
#  'taken': 106881,
#  'care': 15495,
#  'line': 62729,
#  'playing': 84424,
#  'hell': 47258,
#  'getting': 42313,
#  'supply': 105845,
#  'kid': 58699,
#  'family': 36490,
#  'unionizing': 115606,
#  'coronavirusoutbreak': 22191,
#  'certainty': 16876,
#  'pay': 82090,
#  'benefit': 9375,
#  'bos': 12194,
#  'stalled': 103007,
#  'canceled': 15016,
#  'negotiation': 74609,
#  'union': 115596,
#  'busting': 14227,
#  'stand': 103040,
#  'individual': 52086,
#  'fighting': 37634,
#  'right': 92908,
#  'bargain': 8038,
#  'unionsforall': 115611,
#  'fear': 37061,
#  'pestilence': 83032,
#  'lay': 61064,
#  'waste': 119438,
#  'outside': 80382,
#  'psalm': 87470,
#  'tehilim': 107961,
#  'chag': 17004,
#  'semeach': 97508,
#  'covoid': 23135,
#  'vsco': 118764,
#  'vscoedit': 118766,
#  'southafrica': 101828,
#  'israel': 53897,
#  'orlando': 79926,
#  'moscow': 71644,
#  'telaviv': 107983,
#  'miami': 69097,
#  'fortlauderdale': 39522,
#  'ordering': 79796,
#  'local': 63449,
#  'restaurant': 92158,
#  'directly': 28265,
#  'rd': 89804,
#  'party': 81602,
#  'delivery': 26733,
#  'coronavirususa': 22266,
#  'popville': 85308,
#  'venn': 117477,
#  'diagram': 27799,
#  'think': 110362,
#  'ignore': 50875,
#  'science': 96555,
#  'return': 92386,
#  'homophone': 48788,
#  'post': 85507,
#  'environment': 34213,
#  'result': 92230,
#  'contraction': 21293,
#  'flag': 38281,
#  'carrier': 15834,
#  'merge': 68747,
#  'asked': 5941,
#  'dl': 29118,
#  'president': 86257,
#  'trump': 113390,
#  'say': 96089,
#  'airline': 2063,
#  'bailout': 7620,
#  'discussion': 28487,
#  'usatodaytravel': 116459,
#  'best': 9669,
#  'putting': 88076,
#  'athlete': 6307,
#  'position': 85442,
#  'time': 111105,
#  'training': 112539,
#  'requiring': 91878,
#  'support': 105852,
#  'order': 79794,
#  'camp': 14928,
#  'ufc': 114783,
#  'live': 63076,
#  'california': 14685,
#  'cdphdirector': 16585,
#  'dr': 30348,
#  'sonia': 101540,
#  'angell': 4087,
#  'lead': 61191,
#  'public': 87628,
#  'health': 46770,
#  'start': 103184,
#  'spread': 102592,
#  'word': 122536,
#  'vital': 118373,
#  'access': 572,
#  'direct': 28255,
#  'source': 101812,
#  'publichealth': 87650,
#  'information': 52372,
#  'stayhome': 103460,
#  'constant': 21077,
#  'hrh': 49494,
#  'approved': 4938,
#  'emrahangout': 33658,
#  'rotation': 94032,
#  'picked': 83747,
#  'specialty': 102166,
#  'universe': 115735,
#  'change': 17113,
#  'emrahasyourback': 33660,
#  'emrafamily': 33657,
#  'emraanswers': 33656,
#  'emresidents': 33665,
#  'tribute': 113040,
#  'responder': 92109,
#  'rdmaw': 89820,
#  'band': 7836,
#  'mcasmiramarca': 67514,
#  'operationgratitude': 79592,
#  'marine': 66342,
#  'rdmawband': 89821,
#  'firstresponders': 38086,
#  'mcasmiramar': 67513,
#  'allegiant': 2751,
#  'air': 2021,
#  'sponsorship': 102470,
#  'unaffected': 115070,
#  'downturn': 30257,
#  'vega': 117362,
#  'raider': 89194,
#  'stadium': 102940,
#  'hey': 47736,
#  'fam': 36463,
#  'question': 88774,
#  'starting': 103188,
#  'mind': 69896,
#  'maybe': 67316,
#  'encourage': 33746,
#  'msm': 72214,
#  'coverage': 22750,
#  'ump': 115048,
#  'propaganda': 87071,
#  'fest': 37419,
#  'shyt': 99354,
#  'got': 43893,
#  'petro': 83169,
#  'low': 64379,
#  'damn': 25065,
#  'filled': 37702,
#  'whip': 121257,
#  'attorney': 6544,
#  'derickalmena': 27193,
#  'visited': 118306,
#  'client': 19502,
#  'jail': 54556,
#  'today': 111558,
#  'honestly': 48807,
#  'horrible': 49033,
#  'couple': 22670,
#  'teeth': 107948,
#  'left': 61458,
#  'mouth': 71868,
#  'almena': 2953,
#  'vulnerable': 118805,
#  'want': 119207,
#  'court': 22702,
#  'let': 61777,
#  'early': 31833,
#  'nbcbayarea': 74169,
#  'stayhomekc': 103509,
#  'protectingtheprotectorskc': 87218,
#  'retweet': 92402,
#  'kcmohealthdept': 57892,
#  'reminder': 91248,
#  'stayhomesavelives': 103539,
#  'kcmo': 57890,
#  'new': 74927,
#  'dashboard': 25462,
#  'kcstrong': 57923,
#  'mr': 71993,
#  'eve': 35212,
#  'okay': 78758,
#  'love': 64144,
#  'country': 22629,
#  'watch': 119459,
#  'video': 117833,
#  'shiva': 98941,
#  'ayyadurai': 7169,
#  'share': 98398,
#  'info': 52352,
#  'father': 36821,
#  'firefauci': 37986,
#  'endtheshutdown': 33867,
#  'nc': 74218,
#  'launched': 60894,
#  'online': 79270,
#  'search': 97023,
#  'tool': 111973,
#  'reckless': 90361,
#  'moron': 71563,
#  'moment': 71012,
#  'day': 25784,
#  'idiocracy': 50647,
#  'stayhomestaysafe': 103558,
#  'informative': 52381,
#  'thread': 110669,
#  'thanks': 108636,
#  'eureka': 35133,
#  'chamber': 17064,
#  'special': 102136,
#  'newsletter': 75192,
#  'latest': 60785,
#  'update': 116141,
#  'togetherwearestronger': 111661,
#  'humboldt': 49776,
#  'impact': 51518,
#  'placed': 84237,
#  'set': 97954,
#  'million': 69821,
#  'rental': 91393,
#  'relief': 91136,
#  'fund': 40811,
#  'boston': 12236,
#  'risk': 93131,
#  'losing': 64015,
#  'housing': 49282,
#  'deadline': 26071,
#  'apply': 4893,
#  'tomorrow': 111844,
#  'familiar': 36476,
#  'pattern': 81940,
#  'map': 66094,
#  'mobility': 70762,
#  'rate': 89606,
#  'mortality': 71606,
#  'race': 88973,
#  'ethnicity': 35038,
#  'demographic': 26889,
#  'sdoh': 96937,
#  'feeling': 37214,
#  'mom': 70997,
#  'text': 108516,
#  'test': 108361,
#  'came': 14875,
#  'flu': 38747,
#  'akacapp': 2182,
#  'death': 26154,
#  'unemployed': 115408,
#  'person': 82924,
#  'higher': 47890,
#  'employed': 33581,
#  'relative': 91077,
#  'associated': 6147,
#  'unemployment': 115413,
#  'men': 68474,
#  'woman': 122330,
#  'cv': 24601,
#  'tuning': 114073,
#  'village': 117939,
#  'adam': 972,
#  'trustee': 113773,
#  'board': 11634,
#  'positive': 85448,
#  'case': 15936,
#  'related': 91065,
#  'gold': 43427,
#  'crest': 23566,
#  'retirement': 92335,
#  'center': 16759,
#  'social': 101059,
#  'chenxiwang': 17618,
#  'free': 39959,
#  'software': 101275,
#  'service': 97910,
#  'enterprise': 34119,
#  'remote': 91277,
#  'mobile': 70745,
#  'app': 4813,
#  'devs': 27665,
#  'governor': 44015,
#  'gavin': 41599,
#  'newsom': 75213,
#  'announces': 4344,
#  'allow': 2879,
#  'healthcare': 46784,
#  'healthcorp': 46825,
#  'stay': 103352,
#  'hotel': 49143,
#  'cost': 22482,
#  'pandemic': 81063,
#  'drmmurphy': 30953,
#  'sargsyanz': 95800,
#  'agree': 1845,
#  'asking': 5956,
#  'patient': 81844,
#  'far': 36628,
#  'history': 48205,
#  'rtn': 94240,
#  'est': 34901,
#  'visit': 118290,
#  'esp': 34755,
#  'food': 39061,
#  'toiletry': 111708,
#  'coughing': 22559,
#  'cop': 21532,
#  'tell': 108061,
#  'policing': 84989,
#  'officer': 78491,
#  'respect': 92048,
#  'munities': 72589,
#  'serve': 97894,
#  'protect': 87184,
#  'exclusive': 35543,
#  'footage': 39190,
#  'baltimore': 7780,
#  'young': 124127,
#  'man': 65820,
#  'ing': 52412,
#  'funeral': 40843,
#  'arrested': 5464,
#  'despite': 27400,
#  'week': 120178,
#  'half': 45692,
#  'raised': 89259,
#  'partner': 81587,
#  'incredible': 51928,
#  'nyc': 77713,
#  'wburgpizza': 119650,
#  'honeybrainslife': 48814,
#  'chefdavidburke': 17541,
#  'send': 97613,
#  'meal': 67834,
#  'everyday': 35286,
#  'nyphospital': 77936,
#  'sloan': 100381,
#  'kettering': 58471,
#  'unit': 115636,
#  'photo': 83557,
#  'lt': 64537,
#  'gingerrotella': 42627,
#  'mask': 66774,
#  'playitsafe': 84436,
#  'shotonsamsungs': 99132,
#  'pitman': 84121,
#  'jersey': 55481,
#  'watching': 119467,
#  'cnn': 19882,
#  'wavy': 119567,
#  'news': 75147,
#  'alum': 3103,
#  'david': 25610,
#  'culver': 24291,
#  'awesome': 7061,
#  'covering': 22761,
#  'difficult': 27994,
#  'circumstance': 18765,
#  'china': 18004,
#  'sad': 94843,
#  'island': 53818,
#  'renamed': 91333,
#  'coronaviruspandemic': 22198,
#  'trumpliesamericansdie': 113588,
#  'podcast': 84829,
#  'ro': 93325,
#  'murda': 72685,
#  'ix': 54374,
#  'ine': 52176,
#  'ramel': 89359,
#  'pierson': 83849,
#  'security': 97202,
#  'scam': 96210,
#  'gym': 45419,
#  'open': 79476,
#  'nycmayor': 77779,
#  'billdeblasio': 10350,
#  'unanswered': 115083,
#  'pb': 82147,
#  'ok': 78756,
#  'smart': 100546,
#  'curious': 24419,
#  'exponentialgrowth': 35804,
#  'testing': 108383,
#  'site': 99902,
#  'mccc': 67539,
#  'residential': 91968,
#  'area': 5188,
#  'street': 104751,
#  'protected': 87198,
#  'influx': 52351,
#  'potentially': 85606,
#  'sick': 99381,
#  'blue': 11427,
#  'bell': 9246,
#  'rephanbidge': 91598,
#  'vaark': 116889,
#  'whitpaintwp': 121377,
#  'kenlawrencejr': 58318,
#  'repdean': 91542,
#  'montcopa': 71291,
#  'clo': 19603,
#  'deal': 26100,
#  'issued': 53927,
#  'month': 71334,
#  'expanded': 35664,
#  'talf': 106957,
#  'program': 86912,
#  'issuance': 53924,
#  'trend': 112950,
#  'interesting': 53063,
#  'leveragedloan': 61962,
#  'cloperformance': 19619,
#  'creditrating': 23515,
#  'shennanigans': 98691,
#  'miss': 70226,
#  'sydney': 106556,
#  'luck': 64627,
#  'ortho': 79976,
#  'teamwork': 107789,
#  'workdistancing': 122574,
#  'kaiser': 57356,
#  'permanente': 82841,
#  'south': 101827,
#  'sacramento': 94810,
#  'hate': 46412,
#  'governortomwolf': 44045,
#  'padems': 80806,
#  'pahealthdept': 80847,
#  'bringing': 13206,
#  'neighborhood': 74625,
#  'stop': 104445,
#  'teaching': 107581,
#  'nephew': 74733,
#  'game': 41268,
#  'iamthegamechanger': 50311,
#  'hustlehardneverbeg': 49970,
#  'essentialbusiness': 34840,
#  'havefaith': 46482,
#  'changer': 17129,
#  'apparel': 4824,
#  'rep': 91475,
#  'detroit': 27521,
#  'clean': 19332,
#  'gum': 45230,
#  'wall': 119105,
#  'pike': 83870,
#  'market': 66407,
#  'raise': 89257,
#  'hospitality': 49095,
#  'real': 89943,
#  'virtual': 118122,
#  'created': 23434,
#  'seattle': 97058,
#  'trying': 113818,
#  'closed': 19637,
#  'story': 104600,
#  'approx': 4942,
#  'kiro': 59066,
#  'nytimes': 78015,
#  'press': 86310,
#  'briefing': 13119,
#  'nation': 73852,
#  'state': 103250,
#  'progress': 86922,
#  'solving': 101418,
#  'american': 3399,
#  'dead': 26052,
#  'crowing': 23829,
#  'rating': 89615,
#  'desperate': 27385,
#  'grieving': 44752,
#  'king': 58948,
#  'shame': 98314,
#  'grand': 44266,
#  'beef': 8974,
#  'stew': 104107,
#  'rainy': 89248,
#  'fortfood': 39488,
#  'rainysocaldays': 89255,
#  'aprilshowersbringmayflowers': 4991,
#  'quarantinelife': 88461,
#  'pasadena': 81634,
#  'socialdistance': 101081,
#  'hope': 48929,
#  'taking': 106920,
#  'outdoors': 80287,
#  'went': 120524,
#  'hike': 47987,
#  'afternoon': 1667,
#  'peaceful': 82273,
#  'socialdistancing': 101095,
#  'naturelovers': 74053,
#  'sunshine': 105664,
#  'exercise': 35585,
#  'thursdaymotivation': 110833,
#  'important': 51629,
#  'message': 68818,
#  'relayed': 91092,
#  'restructure': 92224,
#  'build': 13859,
#  'society': 101196,
#  'working': 122623,
#  'hiap': 47822,
#  'interdependence': 53053,
#  'spoke': 102449,
#  'sbagov': 96135,
#  'administrator': 1222,
#  'team': 107602,
#  'reporting': 91717,
#  'funded': 40821,
#  'emergency': 33356,
#  'loan': 63430,
#  'borrower': 12189,
#  'lender': 61626,
#  'le': 61188,
#  'meaning': 67853,
#  'small': 100479,
#  'business': 14161,
#  'careact': 15496,
#  'similarity': 99637,
#  'knew': 59283,
#  'pre': 85981,
#  'context': 21249,
#  'frustrating': 40497,
#  'affected': 1527,
#  'life': 62267,
#  'host': 49121,
#  'erica': 34475,
#  'robert': 93397,
#  'brandon': 12662,
#  'knox': 59378,
#  'damaxrecords': 25043,
#  'spreaker': 102628,
#  'brandonknox': 12668,
#  'ericaroberts': 34481,
#  'unprecedented': 115888,
#  'unpresident': 115898,
#  'make': 65515,
#  'sense': 97727,
#  'hoping': 48976,
#  'fact': 36172,
#  'faster': 36782,
#  'virus': 118235,
#  'corona': 21744,
#  'sitthefuckdown': 99916,
#  'manhattan': 65934,
#  'york': 124028,
#  'taste': 107267,
#  'recovered': 90429,
#  'observation': 78201,
#  'tolerance': 111734,
#  'spicy': 102291,
#  'significantly': 99522,
#  'decreased': 26386,
#  'craving': 23362,
#  'tongue': 111881,
#  'used': 116522,
#  'eat': 32038,
#  'ease': 31913,
#  'world': 122717,
#  'heal': 46752,
#  'covidiot': 22938,
#  'oflockdown': 78572,
#  'head': 46699,
#  'evening': 35225,
#  'lightitblue': 62493,
#  'extend': 35856,
#  'gratitude': 44404,
#  'appreciation': 4917,
#  'frontline': 40424,
#  'hero': 47610,
#  'fearless': 37073,
#  'salute': 95235,
#  'breakfast': 12794,
#  'dinner': 28189,
#  'kind': 58911,
#  'night': 75706,
#  'tryingnottoboremyfamilywiththesamemeals': 113819,
#  'wewillgetthroughthistogether': 120831,
#  'saferathome': 94932,
#  'laguardo': 60266,
#  'tennessee': 108201,
#  'idea': 50595,
#  'reaching': 89843,
#  'peak': 82299,
#  'pretty': 86387,
#  'premature': 86119,
#  'talking': 106978,
#  'region': 90890,
#  'looking': 63839,
#  'forward': 39577,
#  'hearing': 46990,
#  'condoleezzarice': 20689,
#  'thought': 110647,
#  'fan': 36575,
#  'hooverinst': 48923,
#  'bad': 7461,
#  'wake': 118988,
#  'stuff': 105053,
#  'paying': 82113,
#  'attention': 6519,
#  'robin': 93453,
#  'williams': 121762,
#  'robinwilliams': 93471,
#  'goodmanhunting': 43652,
#  'robinhood': 93457,
#  'covidiots': 22944,
#  'rvawonk': 94594,
#  'mean': 67845,
#  'sorta': 101694,
#  'handle': 45862,
#  'lisadnews': 62849,
#  'newshour': 75185,
#  'senator': 97557,
#  'mitch': 70411,
#  'mcconnell': 67558,
#  'captiol': 15370,
#  'hill': 48019,
#  'foot': 39189,
#  'away': 7043,
#  'lisa': 62840,
#  'wetatvfm': 120779,
#  'cpbmedia': 23196,
#  'pbsnews': 82172,
#  'seriously': 97868,
#  'careful': 15527,
#  'wearing': 119972,
#  'leaving': 61370,
#  'house': 49221,
#  'fashion': 36721,
#  'remember': 91228,
#  'geek': 41782,
#  'pair': 80901,
#  'dark': 25379,
#  'cool': 21473,
#  'gangsta': 41356,
#  'use': 116519,
#  'carolina': 15742,
#  'date': 25516,
#  'esri': 34820,
#  'mlb': 70582,
#  'throwback': 110753,
#  'worldseries': 122773,
#  'wow': 122880,
#  'gospel': 43880,
#  'symbolically': 106591,
#  'wash': 119343,
#  'needful': 74510,
#  'holyweek': 48570,
#  'popefrancis': 85257,
#  'facemasks': 36113,
#  'website': 120068,
#  'finedesignsint': 37883,
#  'discoverlondonohio': 28450,
#  'fine': 37875,
#  'design': 27319,
#  'interior': 53083,
#  'melinda': 68340,
#  'peter': 83073,
#  'elliott': 33134,
#  'consistently': 21042,
#  'knowledgeable': 59350,
#  'council': 22578,
#  'session': 97951,
#  'mist': 70377,
#  'attendee': 6512,
#  'example': 35477,
#  'engagement': 33938,
#  'advocacy': 1431,
#  'parent': 81389,
#  'fyi': 41077,
#  'realdonaldtrump': 89987,
#  'reliable': 91128,
#  'scientific': 96596,
#  'evidence': 35367,
#  'hydroxychloroquine': 50069,
#  'effective': 32641,
#  'overwhelming': 80590,
#  'fatal': 36799,
#  'effect': 32638,
#  'crooked': 23768,
#  'donald': 29619,
#  'succeed': 105283,
#  'unrepentant': 115937,
#  'criminal': 23606,
#  'vote': 118650,
#  'office': 78478,
#  'prosecute': 87142,
#  'crime': 23598,
#  'enablers': 33691,
#  'congress': 20858,
#  'overwhelmed': 80589,
#  'quarantine': 88332,
#  'checkout': 17468,
#  'pulte': 87839,
#  'teampulte': 107733,
#  'feel': 37205,
#  'opportunity': 79651,
#  'difference': 27979,
#  'bekind': 9181,
#  'hometogether': 48757,
#  'alo': 2973,
#  'ogether': 78596,
#  'coping': 21553,
#  'tremendous': 112942,
#  'challenge': 17049,
#  'resilience': 91990,
#  'happier': 46012,
#  'healthier': 46862,
#  'read': 89862,
#  'surviving': 106113,
#  'thriving': 110720,
#  'idaho': 50567,
#  'nurse': 77532,
#  'headed': 46706,
#  'fight': 37603,
#  'chatted': 17393,
#  'earlier': 31831,
#  'assignment': 6128,
#  'expects': 35687,
#  'tbt': 107441,
#  'christmas': 18429,
#  'called': 14738,
#  'speak': 102106,
#  'piece': 83809,
#  'try': 113814,
#  'figure': 37673,
#  'phrase': 83620,
#  'russian': 94514,
#  'roulette': 94061,
#  'nomore': 76448,
#  'fun': 40789,
#  'excited': 35530,
#  'robust': 93505,
#  'randomized': 89438,
#  'controlled': 21326,
#  'trial': 113015,
#  'provide': 87396,
#  'insane': 52678,
#  'gramophone': 44261,
#  'offered': 78472,
#  'growler': 44967,
#  'draft': 30362,
#  'beer': 9007,
#  'medical': 68011,
#  'professional': 86841,
#  'folk': 38955,
#  'little': 62981,
#  'smarter': 100554,
#  'stlouis': 104317,
#  'stl': 104295,
#  'grocery': 44848,
#  'shopping': 99041,
#  'repost': 91728,
#  'nextdoor': 75376,
#  'staysafe': 103665,
#  'omg': 79037,
#  'wakeup': 119015,
#  'instadaily': 52797,
#  'instagram': 52819,
#  'instamood': 52852,
#  'mood': 71362,
#  'leavingthisrighthere': 61373,
#  'mercial': 68698,
#  'tony': 111907,
#  'tiger': 110977,
#  'gonna': 43573,
#  'slow': 100408,
#  'piano': 83714,
#  'melody': 68378,
#  'tuckercarlson': 113942,
#  'pragmatic': 85855,
#  'honest': 48804,
#  'thoughtful': 110649,
#  'thank': 108598,
#  'foxnews': 39690,
#  'restaurantimpossible': 92163,
#  'showing': 99184,
#  'symptom': 106608,
#  'exposed': 35814,
#  'sending': 97623,
#  'prematurely': 86120,
#  'expose': 35813,
#  'irresponsible': 53669,
#  'shut': 99299,
#  'wont': 122444,
#  'reopen': 91429,
#  'katie': 57711,
#  'lmrtn': 63398,
#  'todd': 111576,
#  'totally': 112183,
#  'solarcat': 101318,
#  'quarantinecats': 88369,
#  'portland': 85379,
#  'mequedoencasa': 68657,
#  'en': 33685,
#  'nanban': 73579,
#  'kan': 57440,
#  'windy': 121892,
#  'yey': 123868,
#  'episode': 34339,
#  'phototheday': 83614,
#  'style': 105138,
#  'hat': 46405,
#  'cigar': 18662,
#  'brought': 13487,
#  'daagodfather': 24773,
#  'aka': 2181,
#  'daagodfatherofsolar': 24774,
#  'solarbrotherno': 101317,
#  'selection': 97368,
#  'vendor': 117446,
#  'adding': 1087,
#  'operator': 79608,
#  'manage': 65822,
#  'nevada': 74863,
#  'unemploymentnumber': 115418,
#  'nvleg': 77658,
#  'govwhitmer': 44101,
#  'revising': 92495,
#  'extending': 35862,
#  'experiencing': 35719,
#  'severe': 98023,
#  'shortage': 99080,
#  'ppe': 85764,
#  'frontlines': 40442,
#  'chain': 17012,
#  'act': 841,
#  'fully': 40765,
#  'dpanow': 30294,
#  'getmeppe': 42251,
#  'rn': 93303,
#  'stlcitygov': 104302,
#  'mitted': 70455,
#  'safety': 94952,
#  'including': 51881,
#  'population': 85301,
#  'especially': 34766,
#  'opened': 79498,
#  'sister': 99882,
#  'poor': 85224,
#  'plex': 84579,
#  'cityhopestl': 18881,
#  'shelter': 98661,
#  'unhoused': 115525,
#  'quarantined': 88395,
#  'pun': 87852,
#  'intended': 52997,
#  'davidbroderdo': 25634,
#  'prove': 87383,
#  'relationship': 91070,
#  'government': 43996,
#  'edict': 32406,
#  'disease': 28495,
#  'progression': 86925,
#  'correlation': 22370,
#  'causation': 16290,
#  ...}

# %%
print(len(vect.get_feature_names()))
# Out:
# 124841

# %%
X_train_transformed = vect.transform(X_train)
X_test_transformed =vect.transform(X_test)

# %%
print(type(X_train_transformed))
print(X_train_transformed)
# Out:
# <class 'scipy.sparse.csr.csr_matrix'>
#   (0, 1854)	1
#   (0, 12409)	1
#   (0, 14161)	1
#   (0, 14308)	1
#   (0, 19637)	1
#   (0, 22791)	1
#   (0, 23979)	1
#   (0, 26729)	1
#   (0, 28265)	1
#   (0, 36659)	1
#   (0, 40202)	1
#   (0, 47311)	1
#   (0, 48578)	1
#   (0, 63449)	1
#   (0, 66407)	1
#   (0, 78315)	1
#   (0, 81063)	1
#   (0, 86798)	2
#   (0, 103352)	1
#   (0, 106920)	1
#   (0, 117392)	1
#   (0, 123695)	1
#   (1, 3399)	1
#   (1, 8170)	1
#   (1, 12981)	1
#   :	:
#   (175217, 42313)	1
#   (175217, 47311)	1
#   (175217, 48812)	1
#   (175217, 50069)	1
#   (175217, 61300)	1
#   (175217, 64773)	1
#   (175217, 72589)	1
#   (175217, 79270)	1
#   (175217, 83312)	1
#   (175217, 86217)	1
#   (175217, 99080)	1
#   (175217, 122116)	1
#   (175217, 122559)	1
#   (175218, 3813)	1
#   (175218, 4103)	1
#   (175218, 22791)	1
#   (175218, 33524)	1
#   (175218, 70071)	1
#   (175218, 74488)	1
#   (175218, 77008)	1
#   (175218, 81063)	1
#   (175218, 87670)	1
#   (175218, 90856)	1
#   (175218, 99898)	1
#   (175218, 111558)	1

# %%
from sklearn.naive_bayes import MultinomialNB
mnb = MultinomialNB()

# fit
naive_model = mnb.fit(X_train_transformed,y_train)

# predict class
y_pred_class = mnb.predict(X_test_transformed)

# %%
from sklearn import metrics
metrics.accuracy_score(y_test, y_pred_class)
# Out:
# 0.8767492295400069

# %%
y_pred_class
# Out:
# array([1, 0, 0, ..., 1, 0, 0], dtype=int64)

# %%
x = metrics.confusion_matrix(y_test, y_pred_class)
x
# Out:
# array([[28235,  2786],
#        [ 2613, 10171]], dtype=int64)

# %%
y_pred_class
# Out:
# array([1, 0, 0, ..., 1, 0, 0], dtype=int64)

# %%
confusion = metrics.confusion_matrix(y_test, y_pred_class)
print(confusion)
#[row, column]
TN = confusion[1, 1]
FP = confusion[1, 0]
FN = confusion[0, 1]
TP = confusion[0, 0]
# Out:
# [[28235  2786]
#  [ 2613 10171]]

# %%
sensitivity = TP / float(FN + TP)
print("sensitivity",sensitivity)
# Out:
# sensitivity 0.910189871377454

# %%
specificity = TN / float(TN + FP)

print("specificity",specificity)
# Out:
# specificity 0.7956038798498123

# %%
precision = TP / float(TP + FP)

print("precision",precision)
print(metrics.precision_score(y_test, y_pred_class))
# Out:
# precision 0.9152943464730291
# 0.7849810913019989

# %%
print("precision",precision)
print("PRECISION SCORE :",metrics.precision_score(y_test, y_pred_class))
print("RECALL SCORE :", metrics.recall_score(y_test, y_pred_class))
print("F1 SCORE :",metrics.f1_score(y_test, y_pred_class))
# Out:
# precision 0.9152943464730291
# PRECISION SCORE : 0.7849810913019989
# RECALL SCORE : 0.7956038798498123
# F1 SCORE : 0.7902567887805447

# %%
import joblib
fin_model = naive_model
joblib.dump(fin_model, 'naive_model.joblib')
joblib.dump(vectorizer, 'CountVectorizer.joblib')
# Out:
# ['CountVectorizer.joblib']
